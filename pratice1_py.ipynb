# %% [markdown]
# <a href="https://colab.research.google.com/github/syedsheemafouziya/Python-Beginner-Projects/blob/main/pratice1_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#program to take a age as input and print values entered and its data type
age = int(input("enter ur age: "))
print(age)
print(type(age))
# Out:
# enter ur age: 25
# 25
# <class 'int'>

# %%
#explicit
num = int(input("enter a number: "))
print("the original : ",num,type(num))
num1=float(num)
print("the converted :",num1,type(num1))
# Out:
# enter a number: 345
# the original :  345 <class 'int'>
# the converted : 345.0 <class 'float'>

# %%
#implicit
x=9
y=3.0
print(x+y)
# Out:
# 12.0

# %%
x=int(input("enter a number: "))
y=int(input("enter a number: "))
print(x+y)
print(x-y)
print(x*y)
print(x>y)
# Out:
# enter a number: 45
# enter a number: 36
# 81
# 9
# 1620
# True
