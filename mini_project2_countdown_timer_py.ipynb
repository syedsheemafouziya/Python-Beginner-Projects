# %% [markdown]
# <a href="https://colab.research.google.com/github/syedsheemafouziya/Python-Beginner-Projects/blob/main/mini_project2_countdown_timer_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""Mini Project – Countdown Timer (with 1-second gap)
Goal:
Print a countdown before something “exciting” happens (like “Launching...” or
“Happy New Year!”).
Concepts Used: for loop, range(), and the time module."""
import time
count=int(input("Enter the countdown number: "))
event=input("enter the event name: ")
for i in range(count,0,-1):
  print(i)
  time.sleep(1)
print(event,"🎉")
# Out:
# Enter the countdown number: 5
# enter the event name: happy birthday jani!
# 5
# 4
# 3
# 2
# 1
# happy birthday jani! 🎉
