# %% [markdown]
# <a href="https://colab.research.google.com/github/syedsheemafouziya/Python-Beginner-Projects/blob/main/pratice2_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#take a input and print middle 3 character,last 2 character
str=input("enter a word")
mid=len(str)//2
print(str[mid-1:mid+2])
print(str[-2:])
# Out:
# enter a wordsheema
# eem
# ma

# %%
"""
take a sentence has a input
convet it to lowercase
replace all spaces" " with underscore' _'
print with new string
"""
str=input("enter a sentence")
lower_case = str.lower()
new_string = lower_case.replace(" ",'_')
print(new_string)
# Out:
# enter a sentenceSHEEMA FOUZIYA
# sheema_fouziya
