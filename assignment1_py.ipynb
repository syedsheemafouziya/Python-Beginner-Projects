# %% [markdown]
# <a href="https://colab.research.google.com/github/syedsheemafouziya/Python-Beginner-Projects/blob/main/assignment1_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#print ur name 10 times
n=input("enter ur name: ")
for i in range(10):
  print(n)
# Out:
# enter ur name: sheema
# sheema
# sheema
# sheema
# sheema
# sheema
# sheema
# sheema
# sheema
# sheema
# sheema

# %%
#print ur name 10 times without using loop
n=input("enter ur name: ")

print((n + "\n")*10)
# Out:
# enter ur name: sheema
# sheema
# sheema
# sheema
# sheema
# sheema
# sheema
# sheema
# sheema
# sheema
# sheema
