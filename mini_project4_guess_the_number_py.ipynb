# %% [markdown]
# <a href="https://colab.research.google.com/github/syedsheemafouziya/Python-Beginner-Projects/blob/main/mini_project4_guess_the_number_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""Mini Project – Guess the Number Game
Concepts Used: while loop and user input.
Sample Run:
Guess a number between 1 and 10: 4
Wrong guess! Try again.
Guess again: 7
Congratulations, Saumya! You guessed it right 🎉"""
name=input("Enter your name: ")
secret_number=7
count=1
guess_number=int(input("guess the secret number: "))
while guess_number != secret_number:
  print("Wrong guess! Try again.")
  guess_number=int(input("guess the secret number: "))
  count+=1

if(guess_number==secret_number):
    print(f"Congratulations,{name} You guessed it right 🎉")
print("no of attempts: ",count)
# Out:
# Enter your name: sheema
# guess the secret number: 8
# Wrong guess! Try again.
# guess the secret number: 9
# Wrong guess! Try again.
# guess the secret number: 7
# Congratulations,sheema You guessed it right 🎉
# no of attempts:  3
