# %% [markdown]
# <a href="https://colab.research.google.com/github/syedsheemafouziya/Python-Beginner-Projects/blob/main/predict_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
Predict the output:
x = 5
y = 2.0
print(x // y)
print(x ** y)
"""
x = 5
y = 2.0
print(x // y)
print(x ** y)
# Out:
# 2.0
# 25.0

# %%
"""Identify and correct the error:

if = 10
print(if)
"""
if = 10
print(if)#keyword cant be used has variable
# Out:
#   File "/tmp/ipykernel_553/2424773700.py", line 6
#     if = 10
#        ^
# SyntaxError: invalid syntax
