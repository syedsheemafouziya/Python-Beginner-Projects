# %% [markdown]
# <a href="https://colab.research.google.com/github/syedsheemafouziya/Python-Beginner-Projects/blob/main/assignment2_ipy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#take a diameter has a input and calculate the area of circle
d=float(input("enter the diameter: "))
a=3.14*(d**2)/4
print("area of circle is",a)
# Out:
# enter the diameter: 50
# area of circle is 1962.5
