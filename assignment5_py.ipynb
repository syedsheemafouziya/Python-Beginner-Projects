# %% [markdown]
# <a href="https://colab.research.google.com/github/syedsheemafouziya/Python-Beginner-Projects/blob/main/assignment5_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Create a dictionary storing meanings of 3 English words.
dict ={
    "small":"chota",
    "big":"baada",
    "parents":"ammi pappa"
}
print(dict)
# Out:
# {'small': 'chota', 'big': 'baada', 'parents': 'ammi pappa'}

# %%
#Create a set of numbers and show union and intersection with another set.
set1 = {1,3,9,6,0,4}
set2 ={0,8,6,4,2,1,9}
print("union: ",set1.union(set2))
print("intersection: ",set1.intersection(set2))
# Out:
# union:  {0, 1, 2, 3, 4, 6, 8, 9}
# intersection:  {0, 1, 4, 6, 9}

# %%
"""Try to add both integer 9 and float 9.0 to a set and observe what happens.
 (Hint: You can convert one into a string to make both unique.)
"""
empty_set = set()
empty_set.add(9)
empty_set.add("9.0")
print(empty_set)
# Out:
# {9, '9.0'}
